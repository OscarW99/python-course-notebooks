# %% [markdown]
# <div style="width:100%; background-color:#226c61; color:white; padding:10px; text-align:center; font-size:20px;">
#     <strong>Chapter 3: Data Structures</strong>
# </div>

# %% [markdown]
# <div style="text-align:center; font-size:28px; font-weight:bold;">
#     Tuple Conversion
# </div>

# %% [markdown]
# ### 1. Tuple to List
#
# Given the tuple **`base_pair = ('adenine', 'thymine')`**, write a Python statement to convert it to a list and print the result.

# %%
base_pair = ('adenine', 'thymine')

# Your code here

# %% [markdown]
# ### 2. List to Tuple
#
# Create a list **`nucleotides = ['A', 'T', 'C', 'G']`** and write a statement to convert it to a tuple.

# %%
nucleotides = ['A', 'T', 'C', 'G']

# Your code here

# %% [markdown]
# ### 3. Converting and Modifying
#
# Convert a tuple of amino acids into a list, modify it by adding another amino acid, and convert it back to a tuple.

# %%
amino_acids = ('Alanine', 'Cysteine', 'Glycine')

# Your code here
