# %% [markdown]
# <div style="width:100%; background-color:#226c61; color:white; padding:10px; text-align:center; font-size:20px;">
#     <strong>Chapter 1: Variables, Data Types, and Operators</strong>
# </div>

# %% [markdown]
# <div style="text-align:center; font-size:28px; font-weight:bold;">
#     End of Chapter Problems
# </div>

# %% [markdown]
# ### 1. Basic Variable Creation and Printing
#
# Create two variables, one called `dna_sequence` with the value "ATGC" and another called `organism_name` with the value "E. coli". Print both variables in a single print statement separated by a space.

# %%
dna_sequence = 
organism_name = 
print()

# %% [markdown]
# ### 2. Working with Different Data Types
#
# Create four variables demonstrating each data type covered in this chapter:
# - An integer called `number_of_genes` with value 50
# - A float called `mutation_rate` with value 0.15
# - A string called `protein_name` with value "Hemoglobin"
# - A boolean called `is_prokaryote` with value True
#
# Print the type of each variable.

# %%
number_of_genes = 
mutation_rate = 
protein_name = 
is_prokaryote = 

print(type())  # Print type of each variable

# %% [markdown]
# ### 3. Arithmetic Operations
#
# Given two variables `sequence_a_count = 20` and `sequence_b_count = 12`, calculate and print:
# - The sum of both counts
# - The difference between counts
# - The product of both counts
# - sequence_a_count divided by sequence_b_count (keep decimal points)
# - sequence_a_count divided by sequence_b_count (floor division)
# - The remainder when sequence_a_count is divided by sequence_b_count
# - sequence_a_count raised to the power of 2

# %%
sequence_a_count = 20
sequence_b_count = 12

# Calculate and print each operation
sum_result = 
difference_result = 
product_result = 
division_result = 
floor_division_result = 
remainder_result = 
power_result = 

print()  # Print all results

# %% [markdown]
# ### 4. String Operations
#
# Given three nucleotides stored in variables: `nucleotide1 = "A"`, `nucleotide2 = "T"`, and `nucleotide3 = "G"`, use string operators to:
# - Combine all nucleotides into one string
# - Create a sequence that repeats nucleotide1 three times

# %%
nucleotide1 = "A"
nucleotide2 = "T"
nucleotide3 = "G"

combined_sequence = 
repeated_sequence = 

print()
print()

# %% [markdown]
# ### 5. Comparison Operators
#
# Given two temperature readings (`temp1 = 37.5` and `temp2 = 37.0`), use comparison operators to check and print:
# - If temp1 equals temp2
# - If temp1 is greater than temp2
# - If temp1 is less than or equal to 40.0

# %%
temp1 = 37.5
temp2 = 37.0

equal_result = 
greater_result = 
less_equal_result = 

print()
print()
print()

# %% [markdown]
# ### 6. Logical Operators
#
# Given two boolean variables: `is_bacteria = True` and `has_nucleus = False`, use logical operators to check and print:
# - If both conditions are True
# - If either condition is True
# - If is_bacteria is not True

# %%
is_bacteria = True
has_nucleus = False

both_true = 
either_true = 
not_bacteria = 

print()
print()
print()

# %% [markdown]
# ### 7. F-strings
#
# Create an f-string that prints the following sentence using variables `species = "H. sapiens"` and `chromosome_count = 23`:
# "The species H. sapiens has 23 pairs of chromosomes"

# %%
species = "H. sapiens"
chromosome_count = 23

result_string = 
print()

# %% [markdown]
# ### 8. Membership Operators
#
# Given the DNA sequence "ATGCTA" stored in a variable called `dna`, use the in/not in operators to check and print:
# - If "ATG" is in dna
# - If "TTT" is not in dna

# %%
dna = "ATGCTA"

has_atg = 
no_ttt = 

print()
print()

# %% [markdown]
# ### 9. Escape Sequences
#
# Print three DNA sequences first on separate lines using a single print statement with an escape sequence, then print them separated by tabs.

# %%
sequence1 = "ATGC"
sequence2 = "GCTA"
sequence3 = "TATA"

# Print with newlines
print()

# Print with tabs
print()

# %% [markdown]
# ### 10. Combined Operations
#
# Create a variable `result` that performs the following operations:
# - Adds 25 and 5
# - Multiplies the sum by 2
# - Divides the product by 10
#
# Print the final result in an f-string saying "The final result is {result}"

# %%
# Perform calculations
result = 

# Print using f-string
print()
