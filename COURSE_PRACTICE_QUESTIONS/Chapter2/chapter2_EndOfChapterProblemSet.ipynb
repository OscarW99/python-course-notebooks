# %% [markdown]
# <div style="width:100%; background-color:#226c61; color:white; padding:10px; text-align:center; font-size:20px;">
#     <strong>Chapter 2: Conditional Statements and Loops</strong>
# </div>

# %% [markdown]
# <div style="text-align:center; font-size:28px; font-weight:bold;">
#     End of Chapter Problems
# </div>

# %% [markdown]
# ### 1. Temperature Classification
#
# You are analyzing temperature data from various biological experiments. Write a program that classifies temperatures into categories based on their value:
# - Use a for loop to iterate through the list of temperatures
# - Classify temperatures as "Low temperature" if below 37°C
# - Classify temperatures as "Normal range" if between 37°C and 40°C
# - Classify temperatures as "High temperature" if above 40°C

# %%
temperatures = [35, 37, 39, 42, 45, 50]
# Write your solution here

# %% [markdown]
# ### 2. Drug Concentration Reduction
#
# Design a while loop to simulate the reduction of drug concentration during a metabolic experiment. Your program should:
# - Start with an initial drug concentration of 100 mg/mL
# - Reduce the concentration by 15% in each iteration
# - Stop when the concentration falls below 10 mg/mL
# - Print the concentration in each iteration
# - Display the number of iterations (cycles) required to reach the threshold

# %%
# Write your solution here

# %% [markdown]
# ### 3. Codon Sequence Iteration
#
# Write a program that iterates through a list of codons and uses a conditional statement to categorize each codon:
# - If the codon is "ATG", print "Start codon"
# - If the codon is "TAA", "TAG", or "TGA", print "Stop codon"
# - For any other codon, print "Coding codon"

# %%
codons = ['ATG', 'TAA', 'CGT', 'TGA', 'GGC']
# Write your solution here

# %% [markdown]
# ### 4. Experimental Condition Simulation
#
# Create a nested loop to explore different experimental parameters:
# - Use temperatures: 37°C, 40°C, 43°C
# - Use enzyme types: EcoRI, HindIII, BamHI
# - Print all combinations of temperature and enzyme
# - Add a note "High-temperature condition" if temperature is above 40°C

# %%
# Write your solution here

# %% [markdown]
# ### 5. Enzyme Activation Threshold
#
# Write a program to simulate enzyme activation based on temperature:
# - Create a while loop that starts with a temperature of 20°C
# - Increment temperature by 5°C in each iteration
# - Print "Enzyme activated" when temperature reaches or exceeds 37°C
# - Stop the loop when temperature reaches 50°C

# %%
# Write your solution here

# %% [markdown]
# ### 6. Protein Length Verification
#
# Write a program to categorize protein sequences based on their length:
# - Use a for loop to iterate through the sequences
# - Print "Short protein" if sequence length is less than 10
# - Print "Medium protein" if sequence length is between 10 and 20
# - Print "Long protein" if sequence length is greater than 20

# %%
protein_sequences = ['MVHLTPEEKSAV', 'MDAK', 'MKLVINGKVEEANAGGHVDK']
# Write your solution here

# %% [markdown]
# ### 7. Experimental Repetition Analysis
#
# Write a nested loop to simulate experimental iterations:
# - Use sample volumes: [10, 20, 30] µL
# - Use replicate numbers: [1, 2, 3]
# - Print each combination of sample volume and replicate number
# - Add a note "Replicate threshold met" if replicate number is 3

# %%
# Write your solution here

# %% [markdown]
# ### 8. Exponential Growth Simulation
#
# Use the `range()` function to simulate bacterial population growth:
# - Start with an initial population of 100 bacteria
# - Simulate 10 generations of growth
# - In each generation, the population doubles
# - Print the population size for each generation
# - Highlight generations where population exceeds 1600 bacteria

# %%
# Write your solution here

# %% [markdown]
# ### 9. PCR Cycle Simulation
#
# Develop a while loop to simulate DNA amplification:
# - Start with 1 initial DNA copy
# - Target 1000 DNA copies
# - Double DNA copies in each cycle
# - Print the number of cycles required
# - Print the final number of DNA copies

# %%
# Write your solution here

# %% [markdown]
# ### 10. Experimental Threshold Detection
#
# Create a while loop to simulate an experimental process:
# - Start with an initial enzyme activity of 10%
# - Increment enzyme activity by 5% in each iteration
# - Print the current enzyme activity level
# - Print "Optimal activity reached" when activity exceeds 50%
# - Stop the loop when enzyme activity reaches 100%

# %%
# Write your solution here
